# %% [markdown]
# <a href="https://colab.research.google.com/github/StellaMoureah/StellaMoureah/blob/main/inreodu%C3%A7%C3%A3o_a_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("I competição de Programa da Start")
# Out:
# I competição de Programa da Start

# %%
ano = "II"

print(ano, "competição de programação da Start")
# Out:
# II competição de programação da Start

# %%
print(f"{ano} competição de programa da Start")
# Out:
# II competição de programa da Start
